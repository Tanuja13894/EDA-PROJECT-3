# %%
# Import the neccesary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Reading a data with pandas
data = pd.read_csv('/content/housing_data (1).csv')
data.head()
# Out:
#    Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0           0       SC60       RL           65     8450   Pave   NaN      Reg
# 1           1       SC20       RL           80     9600   Pave   NaN      Reg
# 2           2       SC60       RL           68    11250   Pave   NaN      IR1
# 3           3       SC70       RL           60     9550   Pave   NaN      IR1
# 4           4       SC60       RL           84    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 1         Lvl    AllPub  ...        0     No    No          No       0    May
# 2         Lvl    AllPub  ...        0     No    No          No       0    Sep
# 3         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 4         Lvl    AllPub  ...        0     No    No          No       0    Dec
#
# ...

# %%
data.tail()
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 1455        1455       SC60       RL           62     7917   Pave   NaN
# 1456        1456       SC20       RL           85    13175   Pave   NaN
# 1457        1457       SC70       RL           66     9042   Pave   NaN
# 1458        1458       SC20       RL           68     9717   Pave   NaN
# 1459        1459       SC20       RL           75     9937   Pave   NaN
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# 1455      Reg         Lvl    AllPub  ...        0     No     No          No
# 1456      Reg         Lvl    AllPub  ...        0     No  MnPrv          No
# 1457      Reg         Lvl    AllPub  ...        0     No  GdPrv        Shed
# 1458      Reg         Lvl    AllPub  ...        0     No     No          No
# 1459      Reg         Lvl    AllPub  ...        0     No     No          No
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
data
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 0              0       SC60       RL           65     8450   Pave   NaN
# 1              1       SC20       RL           80     9600   Pave   NaN
# 2              2       SC60       RL           68    11250   Pave   NaN
# 3              3       SC70       RL           60     9550   Pave   NaN
# 4              4       SC60       RL           84    14260   Pave   NaN
# ...          ...        ...      ...          ...      ...    ...   ...
# 1455        1455       SC60       RL           62     7917   Pave   NaN
# 1456        1456       SC20       RL           85    13175   Pave   NaN
# 1457        1457       SC70       RL           66     9042   Pave   NaN
# 1458        1458       SC20       RL           68     9717   Pave   NaN
# 1459        1459       SC20       RL           75     9937   Pave   NaN
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
data.describe()
# Out:
#         Unnamed: 0  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean    729.500000    57.623288   10516.828082     6.099315     5.575342
# std     421.610009    34.664304    9981.264932     1.382997     1.112799
# min       0.000000     0.000000    1300.000000     1.000000     1.000000
# 25%     364.750000    42.000000    7553.500000     5.000000     5.000000
# 50%     729.500000    63.000000    9478.500000     6.000000     5.000000
# 75%    1094.250000    79.000000   11601.500000     7.000000     6.000000
# max    1459.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1460.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.117123   443.639726    46.549315  ...
# std      30.202904     20.645407   180.731373   456.098091   161.319273  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1460 non-null   int64
#  1   MSSubClass     1460 non-null   object
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   int64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
#Find the total number of missing values from the entire data
data.isnull().sum().sum()
# Out:
# 2323

# %%
data.isnull().sum()
# Out:
# Unnamed: 0       0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 81, dtype: int64

# %%
#Deleting the entire row
data1=data.dropna(axis=0)

# %%
data1.shape
# Out:
# (13, 81)

# %%
dataf=data.drop(['Unnamed: 0'],axis=1)

# %%
data.shape
# Out:
# (1460, 81)

# %%
data.shape[0]
# Out:
# 1460

# %%
data.shape[1]
# Out:
# 81

# %%
# Check for duplicates
duplicates = data.duplicated()

# %%
# Print the number of duplicates
print(duplicates.sum())
# Out:
# 0

# %%
data.drop_duplicates()
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 0              0       SC60       RL           65     8450   Pave   NaN
# 1              1       SC20       RL           80     9600   Pave   NaN
# 2              2       SC60       RL           68    11250   Pave   NaN
# 3              3       SC70       RL           60     9550   Pave   NaN
# 4              4       SC60       RL           84    14260   Pave   NaN
# ...          ...        ...      ...          ...      ...    ...   ...
# 1455        1455       SC60       RL           62     7917   Pave   NaN
# 1456        1456       SC20       RL           85    13175   Pave   NaN
# 1457        1457       SC70       RL           66     9042   Pave   NaN
# 1458        1458       SC20       RL           68     9717   Pave   NaN
# 1459        1459       SC20       RL           75     9937   Pave   NaN
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
#Removing 4th indexed value from the dataframe
data.drop(4).head()
# Out:
#    Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0           0       SC60       RL           65     8450   Pave   NaN      Reg
# 1           1       SC20       RL           80     9600   Pave   NaN      Reg
# 2           2       SC60       RL           68    11250   Pave   NaN      IR1
# 3           3       SC70       RL           60     9550   Pave   NaN      IR1
# 5           5       SC50       RL           85    14115   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0     No     No          No       0
# 1         Lvl    AllPub  ...        0     No     No          No       0
# 2         Lvl    AllPub  ...        0     No     No          No       0
# 3         Lvl    AllPub  ...        0     No     No          No       0
# 5         Lvl    AllPub  ...        0     No  MnPrv        Shed     700
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
data["LotArea"].unique()
# Out:
# array([ 8450,  9600, 11250, ..., 17217, 13175,  9717])

# %%
data["LotArea"].nunique()
# Out:
# 1073

# %%
data.replace()
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 0              0       SC60       RL           65     8450   Pave   NaN
# 1              1       SC20       RL           80     9600   Pave   NaN
# 2              2       SC60       RL           68    11250   Pave   NaN
# 3              3       SC70       RL           60     9550   Pave   NaN
# 4              4       SC60       RL           84    14260   Pave   NaN
# ...          ...        ...      ...          ...      ...    ...   ...
# 1455        1455       SC60       RL           62     7917   Pave  Pave
# 1456        1456       SC20       RL           85    13175   Pave  Pave
# 1457        1457       SC70       RL           66     9042   Pave  Pave
# 1458        1458       SC20       RL           68     9717   Pave  Pave
# 1459        1459       SC20       RL           75     9937   Pave  Pave
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
data.sort_values(by='LotArea', ascending=False).head()
# Out:
#      Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 313         313       SC20       RL          150   215245   Pave   NaN
# 335         335      SC190       RL            0   164660   Grvl   NaN
# 249         249       SC50       RL            0   159000   Pave   NaN
# 706         706       SC20       RL            0   115149   Pave   NaN
# 451         451       SC20       RL           62    70761   Pave   NaN
#
#     LotShape LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature  \
# 313      IR3         Low    AllPub  ...        0     No    No          No
# 335      IR1         HLS    AllPub  ...        0     No    No        Shed
# 249      IR2         Low    AllPub  ...        0     No    No        Shed
# 706      IR2         Low    AllPub  ...        0     No    No          No
# 451      IR1         Low    AllPub  ...        0     No    No          No
#
#     MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
data.sort_values(by='LotArea', ascending=True).head()
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 956          956      SC160       RM           24     1300   Pave   NaN
# 1039        1039      SC180       RM           21     1477   Pave   NaN
# 614          614      SC180       RM           21     1491   Pave   NaN
# 489          489      SC180       RM           21     1526   Pave   NaN
# 1449        1449      SC180       RM           21     1533   Pave   NaN
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# 956       Reg         Lvl    AllPub  ...        0     No  GdPrv          No
# 1039      Reg         Lvl    AllPub  ...        0     No     No          No
# 614       Reg         Lvl    AllPub  ...        0     No     No          No
# 489       Reg         Lvl    AllPub  ...        0     No     No          No
# 1449      Reg         Lvl    AllPub  ...        0     No     No          No
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
num_rows,num_cols =data.shape
print("Number of Rows:", num_rows) #to get no.of rows & columns
print("Number of columns:", num_cols)
# Out:
# Number of Rows: 1460
# Number of columns: 81

# %%
data['GarageArea']=data['GarageArea'].astype('int64')#to get data of GarageArea
data.dtypes['GarageArea']
# Out:
# dtype('int64')

# %%
#filter top 40 datapoints skipping in 1 row
data[1:41:2]
# Out:
#     Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 1            1       SC20       RL           80     9600   Pave   NaN
# 3            3       SC70       RL           60     9550   Pave   NaN
# 5            5       SC50       RL           85    14115   Pave   NaN
# 7            7       SC60       RL            0    10382   Pave   NaN
# 9            9      SC190       RL           50     7420   Pave   NaN
# 11          11       SC60       RL           85    11924   Pave   NaN
# 13          13       SC20       RL           91    10652   Pave   NaN
# 15          15       SC45       RM           51     6120   Pave   NaN
# 17          17       SC90       RL           72    10791   Pave   NaN
# 19          19       SC20       RL           70     7560   Pave   NaN
# 21          21       SC45       RM           57     7449   Pave  Grvl
# 23          23      SC120       RM           44     4224   Pave   NaN
# ...

# %%
#Replace the missing values for numerical columns with mean
data['YrSold'].fillna(data['SalePrice'].mean())
# Out:
# 0       2008
# 1       2007
# 2       2008
# 3       2006
# 4       2008
#         ...
# 1455    2007
# 1456    2010
# 1457    2010
# 1458    2010
# 1459    2008
# Name: YrSold, Length: 1460, dtype: int64

# %%
# Transpose the data to have a different look at the data
data.head().T
# Out:
#                     0       1       2        3       4
# Unnamed: 0          0       1       2        3       4
# MSSubClass       SC60    SC20    SC60     SC70    SC60
# MSZoning           RL      RL      RL       RL      RL
# LotFrontage        65      80      68       60      84
# LotArea          8450    9600   11250     9550   14260
# ...               ...     ...     ...      ...     ...
# MoSold            Feb     May     Sep      Feb     Dec
# YrSold           2008    2007    2008     2006    2008
# SaleType           WD      WD      WD       WD      WD
# SaleCondition  Normal  Normal  Normal  Abnorml  Normal
# SalePrice      208500  181500  223500   140000  250000
#
# [81 rows x 5 columns]

# %%
dataf
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          SC60       RL           65     8450   Pave   NaN      Reg
# 1          SC20       RL           80     9600   Pave   NaN      Reg
# 2          SC60       RL           68    11250   Pave   NaN      IR1
# 3          SC70       RL           60     9550   Pave   NaN      IR1
# 4          SC60       RL           84    14260   Pave   NaN      IR1
# ...         ...      ...          ...      ...    ...   ...      ...
# 1455       SC60       RL           62     7917   Pave   NaN      Reg
# 1456       SC20       RL           85    13175   Pave   NaN      Reg
# 1457       SC70       RL           66     9042   Pave   NaN      Reg
# 1458       SC20       RL           68     9717   Pave   NaN      Reg
# 1459       SC20       RL           75     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %% [markdown]
# Imputing the Missing Value

# %%
#Replace the missing value with '0' using 'fiilna' method
data['Alley'].fillna(0)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1455    0
# 1456    0
# 1457    0
# 1458    0
# 1459    0
# Name: Alley, Length: 1460, dtype: object

# %%
data.fillna(1)
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 0              0       SC60       RL           65     8450   Pave     1
# 1              1       SC20       RL           80     9600   Pave     1
# 2              2       SC60       RL           68    11250   Pave     1
# 3              3       SC70       RL           60     9550   Pave     1
# 4              4       SC60       RL           84    14260   Pave     1
# ...          ...        ...      ...          ...      ...    ...   ...
# 1455        1455       SC60       RL           62     7917   Pave     1
# 1456        1456       SC20       RL           85    13175   Pave     1
# 1457        1457       SC70       RL           66     9042   Pave     1
# 1458        1458       SC20       RL           68     9717   Pave     1
# 1459        1459       SC20       RL           75     9937   Pave     1
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
#Replacing With Mean
#Replace the missing values for numerical columns with mean
data['LotFrontage'].fillna(data['LotFrontage'].mean())
# Out:
# 0       65
# 1       80
# 2       68
# 3       60
# 4       84
#         ..
# 1455    62
# 1456    85
# 1457    66
# 1458    68
# 1459    75
# Name: LotFrontage, Length: 1460, dtype: int64

# %%
#Replacing With Mode
#Replace the missing values for categorical columns with mode
data['LotArea'].fillna(data['LotArea'].mode())
# Out:
# 0        8450
# 1        9600
# 2       11250
# 3        9550
# 4       14260
#         ...
# 1455     7917
# 1456    13175
# 1457     9042
# 1458     9717
# 1459     9937
# Name: LotArea, Length: 1460, dtype: int64

# %%
data['SalePrice'].fillna(data['SalePrice'].mode())
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
#Replacing With Median
data['LotFrontage'].fillna(data['LotFrontage'].median())
# Out:
# 0       65
# 1       80
# 2       68
# 3       60
# 4       84
#         ..
# 1455    62
# 1456    85
# 1457    66
# 1458    68
# 1459    75
# Name: LotFrontage, Length: 1460, dtype: int64

# %% [markdown]
# Replacing with previous value – Forward fill

# %%
data['Alley'].fillna(method= 'ffill')
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 1455    Pave
# 1456    Pave
# 1457    Pave
# 1458    Pave
# 1459    Pave
# Name: Alley, Length: 1460, dtype: object

# %%
#Replacing with next value – Backward fill
# Backward-Fill
data['Alley'].fillna(method= 'bfill')
# Out:
# 0       Grvl
# 1       Grvl
# 2       Grvl
# 3       Grvl
# 4       Grvl
#         ...
# 1455     NaN
# 1456     NaN
# 1457     NaN
# 1458     NaN
# 1459     NaN
# Name: Alley, Length: 1460, dtype: object

# %%
#imputing Missing Values For Categorical Features
X = pd.DataFrame({'house':['MoSold',	'YrSold'	,'SaleType','	SaleCondition',	'SalePrice', np.nan]})
X
# Out:
#              house
# 0           MoSold
# 1           YrSold
# 2         SaleType
# 3  \tSaleCondition
# 4        SalePrice
# 5              NaN

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='most_frequent')
imputer.fit_transform(X)
# Out:
# array([['MoSold'],
#        ['YrSold'],
#        ['SaleType'],
#        ['\tSaleCondition'],
#        ['SalePrice'],
#        ['\tSaleCondition']], dtype=object)

# %%
imputer = SimpleImputer(strategy='most_frequent')
imputer.fit(X)
# Out:
# SimpleImputer(strategy='most_frequent')

# %%
imputer.transform(X)
# Out:
# array([['MoSold'],
#        ['YrSold'],
#        ['SaleType'],
#        ['\tSaleCondition'],
#        ['SalePrice'],
#        ['\tSaleCondition']], dtype=object)

# %% [markdown]
# Impute the Value “missing”, which treats it as a Separate Category

# %%
imputer = SimpleImputer(strategy='constant', fill_value='house1')
imputer.fit_transform(X)
# Out:
# array([['MoSold'],
#        ['YrSold'],
#        ['SaleType'],
#        ['\tSaleCondition'],
#        ['SalePrice'],
#        ['house1']], dtype=object)

# %% [markdown]
# Univariate Approach

# %%
imp = SimpleImputer(missing_values=np.nan, strategy='mean')
imp.fit([[1, 2], [np.nan, 3], [7, 6]])
# Out:
# SimpleImputer()

# %%
imp.transform([[1, 2], [np.nan, 3], [7, 6]])
# Out:
# array([[1., 2.],
#        [4., 3.],
#        [7., 6.]])

# %%
X = [[np.nan, 2], [6, np.nan], [7, 6]]
print(imp.transform(X))
# Out:
# [[4.         2.        ]
#  [6.         3.66666667]
#  [7.         6.        ]]

# %% [markdown]
# Multivariate Approach

# %%
cols = ['LotFrontage',	'LotArea'	,	'SalePrice'	]
X = data[cols]
X
# Out:
#       LotFrontage  LotArea  SalePrice
# 0              65     8450     208500
# 1              80     9600     181500
# 2              68    11250     223500
# 3              60     9550     140000
# 4              84    14260     250000
# ...           ...      ...        ...
# 1455           62     7917     175000
# 1456           85    13175     210000
# 1457           66     9042     266500
# 1458           68     9717     142125
# 1459           75     9937     147500
#
# [1460 rows x 3 columns]

# %%
#from sklearn.experimental import enable_iterative_imputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
impute_it = IterativeImputer()
impute_it.fit_transform(X)
# Out:
# array([[6.50000e+01, 8.45000e+03, 2.08500e+05],
#        [8.00000e+01, 9.60000e+03, 1.81500e+05],
#        [6.80000e+01, 1.12500e+04, 2.23500e+05],
#        ...,
#        [6.60000e+01, 9.04200e+03, 2.66500e+05],
#        [6.80000e+01, 9.71700e+03, 1.42125e+05],
#        [7.50000e+01, 9.93700e+03, 1.47500e+05]])

# %%
cols = ['LotArea','SalePrice']
X = data[cols]
X
# Out:
#       LotArea  SalePrice
# 0        8450     208500
# 1        9600     181500
# 2       11250     223500
# 3        9550     140000
# 4       14260     250000
# ...       ...        ...
# 1455     7917     175000
# 1456    13175     210000
# 1457     9042     266500
# 1458     9717     142125
# 1459     9937     147500
#
# [1460 rows x 2 columns]

# %%
impute_it = IterativeImputer()
impute_it.fit_transform(X)
# Out:
# array([[  8450., 208500.],
#        [  9600., 181500.],
#        [ 11250., 223500.],
#        ...,
#        [  9042., 266500.],
#        [  9717., 142125.],
#        [  9937., 147500.]])

# %% [markdown]
# #Nearest Neighbors Imputations (KNNImputer)

# %%
from sklearn.impute import KNNImputer
impute_knn = KNNImputer(n_neighbors=2)
impute_knn.fit_transform(X)
# Out:
# array([[  8450., 208500.],
#        [  9600., 181500.],
#        [ 11250., 223500.],
#        ...,
#        [  9042., 266500.],
#        [  9717., 142125.],
#        [  9937., 147500.]])

# %%
#Checking for missing values using notnull()
# using notnull() function
data.notnull()
# Out:
#       Unnamed: 0  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0           True        True      True         True     True    True  False
# 1           True        True      True         True     True    True  False
# 2           True        True      True         True     True    True  False
# 3           True        True      True         True     True    True  False
# 4           True        True      True         True     True    True  False
# ...          ...         ...       ...          ...      ...     ...    ...
# 1455        True        True      True         True     True    True  False
# 1456        True        True      True         True     True    True  False
# 1457        True        True      True         True     True    True  False
# 1458        True        True      True         True     True    True  False
# 1459        True        True      True         True     True    True  False
#
# ...

# %%
# filling missing value using fillna()
data.fillna(0)
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 0              0       SC60       RL           65     8450   Pave     0
# 1              1       SC20       RL           80     9600   Pave     0
# 2              2       SC60       RL           68    11250   Pave     0
# 3              3       SC70       RL           60     9550   Pave     0
# 4              4       SC60       RL           84    14260   Pave     0
# ...          ...        ...      ...          ...      ...    ...   ...
# 1455        1455       SC60       RL           62     7917   Pave     0
# 1456        1456       SC20       RL           85    13175   Pave     0
# 1457        1457       SC70       RL           66     9042   Pave     0
# 1458        1458       SC20       RL           68     9717   Pave     0
# 1459        1459       SC20       RL           75     9937   Pave     0
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
# will replace  Nan value in dataframe with value -99
data.replace(to_replace = np.nan, value = -99)
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 0              0       SC60       RL           65     8450   Pave   -99
# 1              1       SC20       RL           80     9600   Pave   -99
# 2              2       SC60       RL           68    11250   Pave   -99
# 3              3       SC70       RL           60     9550   Pave   -99
# 4              4       SC60       RL           84    14260   Pave   -99
# ...          ...        ...      ...          ...      ...    ...   ...
# 1455        1455       SC60       RL           62     7917   Pave   -99
# 1456        1456       SC20       RL           85    13175   Pave   -99
# 1457        1457       SC70       RL           66     9042   Pave   -99
# 1458        1458       SC20       RL           68     9717   Pave   -99
# 1459        1459       SC20       RL           75     9937   Pave   -99
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
data
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 0              0       SC60       RL           65     8450   Pave   NaN
# 1              1       SC20       RL           80     9600   Pave   NaN
# 2              2       SC60       RL           68    11250   Pave   NaN
# 3              3       SC70       RL           60     9550   Pave   NaN
# 4              4       SC60       RL           84    14260   Pave   NaN
# ...          ...        ...      ...          ...      ...    ...   ...
# 1455        1455       SC60       RL           62     7917   Pave   NaN
# 1456        1456       SC20       RL           85    13175   Pave   NaN
# 1457        1457       SC70       RL           66     9042   Pave   NaN
# 1458        1458       SC20       RL           68     9717   Pave   NaN
# 1459        1459       SC20       RL           75     9937   Pave   NaN
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
# Boxplot of the LotArea
sns.boxplot(x = data['LotArea'])

plt.show()

# %% [markdown]
# Describe the dataset and remove outliers

# %%
data.describe()
# Out:
#         Unnamed: 0  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean    729.500000    57.623288   10516.828082     6.099315     5.575342
# std     421.610009    34.664304    9981.264932     1.382997     1.112799
# min       0.000000     0.000000    1300.000000     1.000000     1.000000
# 25%     364.750000    42.000000    7553.500000     5.000000     5.000000
# 50%     729.500000    63.000000    9478.500000     6.000000     5.000000
# 75%    1094.250000    79.000000   11601.500000     7.000000     6.000000
# max    1459.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1460.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.117123   443.639726    46.549315  ...
# std      30.202904     20.645407   180.731373   456.098091   161.319273  ...
# ...

# %%
# Boxplot to give the  column
sns.boxplot(x = data['LotArea'])
plt.show()

# %%
#Use the IQR Technique
def iqr_technique(DFcolumn):
  Q1 = np.percentile(DFcolumn, 25)
  Q3 = np.percentile(DFcolumn, 75)
  IQR = Q3 - Q1
  lower_range = Q1 - (1.5 * IQR)
  upper_range = Q3 + (1.5 * IQR)
  return lower_range, upper_range

# %%
lower_range, upper_range = iqr_technique(data['LotArea'])
data =data[(data.LotArea> lower_range) & (data.LotArea<upper_range)]

# %%
# Check that the outliers are removed.
sns.boxplot(x = data['LotArea'])
print(data.shape)
# Out:
# (1391, 81)

# %%
print(data['LotArea'].max())
# Out:
# 17671

# %%
# Distribution of the prices
plt.figure(figsize=(12,5))
sns.set_theme(style="darkgrid")
sns.distplot(data['LotArea'], color=('r'))
plt.xlabel("LotArea", fontsize=14)
plt.ylabel("SalePrice", fontsize=14)
plt.title("Distribution of Area", fontsize = 15)
plt.show()

# %%
#. Total Listinf/property count in each neighbourhood group using count plot
# Count listings in each neighbourhood and store in pandas series
counts = data['LotFrontage'].value_counts()

# Reset the cindes of the series so that the neighbourhood groups become columns in the resulting dataframe
Top_LotFrontage = counts.reset_index()

# Rename the columns of the dataframe to be more descriptive
Top_LotFrontage.columns = ['LotFrontage', 'LotArea']

# Display the results
Top_LotFrontage
# Out:
#      LotFrontage  LotArea
# 0              0      233
# 1             60      142
# 2             70       70
# 3             80       69
# 4             50       56
# ..           ...      ...
# 97           118        1
# 98           137        1
# 99            33        1
# 100          111        1
# 101          153        1
#
# [102 rows x 2 columns]

# %%
# Set the size
plt.figure(figsize = (12, 8))

#create a count plot of the neighbourhood group data
sns.countplot(data['LotFrontage'])

# Set title
plt.title('LotFrontage LotArea in NYC', fontsize=15)

# Set the xlabel
plt.xlabel('LotFrontage', fontsize=10)

#Set the y label
plt.ylabel('Total LotFrontage', fontsize=10)
# Out:
# Text(0, 0.5, 'Total LotFrontage')

# %% [markdown]
# Average price of Each Enighbourhood group using Point Plot

# %%
data.head()
# Out:
#    Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0           0       SC60       RL           65     8450   Pave   NaN      Reg
# 1           1       SC20       RL           80     9600   Pave   NaN      Reg
# 2           2       SC60       RL           68    11250   Pave   NaN      IR1
# 3           3       SC70       RL           60     9550   Pave   NaN      IR1
# 4           4       SC60       RL           84    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 1         Lvl    AllPub  ...        0     No    No          No       0    May
# 2         Lvl    AllPub  ...        0     No    No          No       0    Sep
# 3         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 4         Lvl    AllPub  ...        0     No    No          No       0    Dec
#
# ...

# %%
# Group the HOUSING dataset by LotFrontage  and calculate the mean of each group
#grouped = data.groupby("LotFrontage").mean()
grouped = data.groupby("LotFrontage")["LotArea"].mean()
# Reset the indes of the grouped data so that the LotFrontage group becomes a column
LotFrontage_avg_LotArea = grouped.reset_index()

#Rename the LotArea to 'avg_LotArea'
LotFrontage_avg_LotArea = round(LotFrontage_avg_LotArea.rename(columns={"LotArea": 'avg_LotArea'}), 2)


# Select only the 'LotFrontage', and the avg_price
LotFrontage_avg_LotArea[['LotFrontage', 'avg_LotArea']].head()
# Out:
#    LotFrontage  avg_LotArea
# 0            0      9946.65
# 1           21      1737.95
# 2           24      2340.61
# 3           30      4553.83
# 4           32      5541.80

# %%
# Import mean from the statistics module
from statistics import mean

# Create the pointplot
LotFrontage_avg_LotArea[['LotFrontage', 'avg_LotArea']].head()
sns.pointplot(x = 'LotFrontage', y = 'LotArea', data=data, estimator=np.mean)

# Add axis and labels
plt.xlabel("LotFrontage")
plt.ylabel('Average LotArea')
plt.title('Average LotArea by the LotFrontage ')
# Out:
# Text(0.5, 1.0, 'Average LotArea by the LotFrontage ')

# %%
# LotArea distribution using violin plot
ax = sns.violinplot(x = 'LotFrontage', y = 'LotArea', data = data)

# %%
# Summary Statistics
data.describe()
# Out:
#         Unnamed: 0  LotFrontage       LotArea  OverallQual  OverallCond  \
# count  1391.000000  1391.000000   1391.000000  1391.000000  1391.000000
# mean    728.092739    57.298347   9272.537024     6.091301     5.577283
# std     421.755745    32.000778   3196.732418     1.371709     1.105071
# min       0.000000     0.000000   1491.000000     1.000000     1.000000
# 25%     364.000000    43.000000   7429.000000     5.000000     5.000000
# 50%     730.000000    63.000000   9286.000000     6.000000     5.000000
# 75%    1092.500000    78.000000  11231.500000     7.000000     6.000000
# max    1459.000000   182.000000  17671.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1391.000000   1391.000000  1391.000000  1391.000000  1391.000000  ...
# mean   1971.557872   1984.989216   100.303379   430.020848    43.389648  ...
# std      30.301757     20.676905   173.040603   425.617348   153.444567  ...
# ...

# %%
#Data Visualization
import pandas as pd
import numpy as np
import seaborn as sns

# %%
def removal_box_plot(data, column, threshold):
    sns.boxplot(data[column])
    plt.title(f'Original Box Plot of {column}')
    data_precipitation = pd.read_csv("path/to/precipitation.csv")
    plt.show()

    removed_outliers = data[data[column] <= threshold]

    sns.boxplot(removed_outliers[column])
    plt.title(f'Box Plot without Outliers of {column}')
    plt.show()
    return removed_outliers

# %%
sns.boxplot(data=['LotFrontage','LotArea','OverallQual','OverallCond','YearBuilt','YearRemodAdd'])
['3SsnPorch','ScreenPorch','PoolArea','MiscVal','YrSold','SalePrice']
# Out:
# ['3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'YrSold', 'SalePrice']

# %%
#  Mean, Median, and Mode Imputation
mean_imputation = data['LotArea'].fillna(data['LotArea'].mean())
median_imputation = data['LotArea'].fillna(data['LotArea'].median())
mode_imputation = data['LotArea'].fillna(data['LotArea'].mode().iloc[0])

print("\nImputation using Mean:")
print(mean_imputation)

print("\nImputation using Median:")
print(median_imputation)

print("\nImputation using Mode:")
print(mode_imputation)
# Out:
# Imputation using Mean:
# 0        8450
# 1        9600
# 2       11250
# 3        9550
# 4       14260
#         ...
# 1455     7917
# 1456    13175
# 1457     9042
# 1458     9717
# 1459     9937
# Name: LotArea, Length: 1391, dtype: int64
#
# Imputation using Median:
# 0        8450
# 1        9600
# 2       11250
# 3        9550
# 4       14260
#         ...
# 1455     7917
# 1456    13175
# 1457     9042
# 1458     9717
# 1459     9937
# Name: LotArea, Length: 1391, dtype: int64
#
# Imputation using Mode:
# 0        8450
# 1        9600
# 2       11250
# 3        9550
# 4       14260
#         ...
# 1455     7917
# 1456    13175
# 1457     9042
# 1458     9717
# 1459     9937
# Name: LotArea, Length: 1391, dtype: int64

# %%
linear_interpolation = data['LotFrontage'].interpolate(method='linear')
quadratic_interpolation = data['LotFrontage'].interpolate(method='quadratic')

print("\nLinear Interpolation:")
print(linear_interpolation)

print("\nQuadratic Interpolation:")
print(quadratic_interpolation)
# Out:
# Linear Interpolation:
# 0       65
# 1       80
# 2       68
# 3       60
# 4       84
#         ..
# 1455    62
# 1456    85
# 1457    66
# 1458    68
# 1459    75
# Name: LotFrontage, Length: 1391, dtype: int64
#
# Quadratic Interpolation:
# 0       65
# 1       80
# 2       68
# 3       60
# 4       84
#         ..
# 1455    62
# 1456    85
# 1457    66
# 1458    68
# 1459    75
# Name: LotFrontage, Length: 1391, dtype: int64

# %%
# find skewness in each row
data.skew(axis = 1, skipna = True, numeric_only = True)
# Out:
# 0       5.982471
# 1       5.971433
# 2       5.975024
# 3       5.953062
# 4       5.969109
#           ...
# 1455    5.977450
# 1456    5.961938
# 1457    5.987261
# 1458    5.952910
# 1459    5.954551
# Length: 1391, dtype: float64
